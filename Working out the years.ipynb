# %%
year = 2022
#write the desired workout days here to generate a schedule
weekly_workout_days = ["Tuesday", "Thursday", "Saturday", "Sunday"]

# %%
day_initials = ""
for day in weekly_workout_days:
    day_initials += day[:2] 
workout_freq = len(weekly_workout_days)
day_initials
# Out:
# 'TuThSaSu'

# %%
import datetime  
from datetime import date
import calendar
import pandas as pd

def findDay(date):
    month, day, year = (int(part) for part in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%A")

# %%
if (year % 100 and year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    feb_last = 29
else:
    feb_last = 28

small_months = ["04", "06", "09", "11"]
big_months = ["01", "03", "05", "07", "08", "10", "12"]
months_lst = small_months + big_months + ["02"]
months_lst.sort()
months = {}
for key in months_lst:
    if key in small_months:
        months[key] = 30
    elif key in big_months:
        months[key] = 31
    else:
        months[key] = feb_last

all_year_days = months
for month_key in months:
    days = []
    for day_index in range(1, months[month_key] + 1):
        days.append(month_key + "-" + str(day_index) +  "-" + str(year))
    all_year_days[month_key] = days

# %%
yearly_workout_days = all_year_days

for month_key in all_year_days:
    days = []
    for day in all_year_days[month_key]:
        if findDay(day) in weekly_workout_days:
            days.append(day)
    yearly_workout_days[month_key] = days

# %%
all_months = [yearly_workout_days[month] for month in yearly_workout_days]
desired_days_df = pd.DataFrame(list(all_months)).transpose()
desired_days_df.columns = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
desired_days_df
# Out:
#        January    February       March       April         May        June  \
# 0    01-1-2022   02-1-2022   03-1-2022   04-2-2022   05-1-2022   06-2-2022
# 1    01-2-2022   02-3-2022   03-3-2022   04-3-2022   05-3-2022   06-4-2022
# 2    01-4-2022   02-5-2022   03-5-2022   04-5-2022   05-5-2022   06-5-2022
# 3    01-6-2022   02-6-2022   03-6-2022   04-7-2022   05-7-2022   06-7-2022
# 4    01-8-2022   02-8-2022   03-8-2022   04-9-2022   05-8-2022   06-9-2022
# 5    01-9-2022  02-10-2022  03-10-2022  04-10-2022  05-10-2022  06-11-2022
# 6   01-11-2022  02-12-2022  03-12-2022  04-12-2022  05-12-2022  06-12-2022
# 7   01-13-2022  02-13-2022  03-13-2022  04-14-2022  05-14-2022  06-14-2022
# 8   01-15-2022  02-15-2022  03-15-2022  04-16-2022  05-15-2022  06-16-2022
# 9   01-16-2022  02-17-2022  03-17-2022  04-17-2022  05-17-2022  06-18-2022
# 10  01-18-2022  02-19-2022  03-19-2022  04-19-2022  05-19-2022  06-19-2022
